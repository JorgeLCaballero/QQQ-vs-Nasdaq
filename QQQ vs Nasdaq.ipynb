# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1 = pd.read_csv('QQQ.csv', parse_dates = ['Date'], index_col = ['Date'])
df1.sort_index(inplace= True)
df1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-03-10   51.125000   51.156250   50.281250   51.062500   44.386864
# 1999-03-11   51.437500   51.734375   50.312500   51.312500   44.604156
# 1999-03-12   51.125000   51.156250   49.656250   50.062500   43.517586
# 1999-03-15   50.437500   51.562500   49.906250   51.500000   44.767155
# 1999-03-16   51.718750   52.156250   51.156250   51.937500   45.147457
# ...                ...         ...         ...         ...         ...
# 2021-04-08  334.559998  335.269989  333.739990  335.079987  335.079987
# 2021-04-09  333.679993  337.320007  332.920013  337.109985  337.109985
# 2021-04-12  336.040009  337.100006  334.730011  336.670013  336.670013
# 2021-04-13  338.239990  341.079987  338.019989  340.600006  340.600006
# 2021-04-14  340.850006  340.980011  335.670013  336.510010  336.510010
#
#               Volume
# Date
# 1999-03-10   5232000
# 1999-03-11   9688600
# 1999-03-12   8743600
# ...

# %%
plt.xlabel('Date')
plt.ylabel('Open')
plt.plot(df1)

# %%
df1.index
# Out:
# Index(['1999-03-10', '1999-03-11', '1999-03-12', '1999-03-15', '1999-03-16',
#        '1999-03-17', '1999-03-18', '1999-03-19', '1999-03-22', '1999-03-23',
#        ...
#        '2021-03-31', '2021-04-01', '2021-04-05', '2021-04-06', '2021-04-07',
#        '2021-04-08', '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14'],
#       dtype='object', name='Date', length=5561)

# %%
df2 = pd.read_csv('Nasdaq.csv',parse_dates = ['Date'], index_col = ['Date'])
df2
df2.sort_index(inplace= True)
df2
# Out:
#                     Open          High           Low         Close  \
# Date
# 1971-02-05    100.000000    100.000000    100.000000    100.000000
# 1971-02-08    100.839996    100.839996    100.839996    100.839996
# 1971-02-09    100.760002    100.760002    100.760002    100.760002
# 1971-02-10    100.690002    100.690002    100.690002    100.690002
# 1971-02-11    101.449997    101.449997    101.449997    101.449997
# ...                  ...           ...           ...           ...
# 2021-04-08  13796.889648  13830.139648  13758.709961  13829.309570
# 2021-04-09  13787.019531  13905.410156  13748.349609  13900.190430
# 2021-04-12  13854.440430  13877.000000  13783.950195  13850.000000
# 2021-04-13  13902.450195  14011.509766  13902.450195  13996.099609
# 2021-04-14  14004.080078  14033.629883  13839.040039  13857.839844
#
#                Adj Close      Volume
# Date
# 1971-02-05    100.000000           0
# 1971-02-08    100.839996           0
# ...

# %%
df2.index
# Out:
# DatetimeIndex(['1971-02-05', '1971-02-08', '1971-02-09', '1971-02-10',
#                '1971-02-11', '1971-02-12', '1971-02-16', '1971-02-17',
#                '1971-02-18', '1971-02-19',
#                ...
#                '2021-03-31', '2021-04-01', '2021-04-05', '2021-04-06',
#                '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-12',
#                '2021-04-13', '2021-04-14'],
#               dtype='datetime64[ns]', name='Date', length=12658, freq=None)

# %%
x = df2["Open"].astype(int)
y = df1["Open"].astype(int)

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

sns.lineplot(data=x)

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

sns.lineplot(data=y)

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df11 = df1['Open']
df11
# Out:
# Date
# 1999-03-10     51.125000
# 1999-03-11     51.437500
# 1999-03-12     51.125000
# 1999-03-15     50.437500
# 1999-03-16     51.718750
#                  ...
# 2021-04-08    334.559998
# 2021-04-09    333.679993
# 2021-04-12    336.040009
# 2021-04-13    338.239990
# 2021-04-14    340.850006
# Name: Open, Length: 5561, dtype: float64

# %%
df12 = df2['Open']
df12
# Out:
# Date
# 1971-02-05      100.000000
# 1971-02-08      100.839996
# 1971-02-09      100.760002
# 1971-02-10      100.690002
# 1971-02-11      101.449997
#                   ...
# 2021-04-08    13796.889648
# 2021-04-09    13787.019531
# 2021-04-12    13854.440430
# 2021-04-13    13902.450195
# 2021-04-14    14004.080078
# Name: Open, Length: 12658, dtype: float64

# %%
rolling_mean = df11.rolling(window = 12).mean()
rolling_std = df11.rolling(window = 12).std()
plt.plot(df11, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
rolling_mean = df12.rolling(window = 12).mean()
rolling_std = df12.rolling(window = 12).std()
plt.plot(df12, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
result = adfuller(df11)
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ADF Statistic: 4.372455337302769
# p-value: 1.0
# Critical Values:
# 	1%: -3.431532207416466
# 	5%: -2.8620624189367487
# 	10%: -2.5670480823255235

# %%
result = adfuller(df12)
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ADF Statistic: 5.4013431388818995
# p-value: 1.0
# Critical Values:
# 	1%: -3.4308684393652285
# 	5%: -2.861769124592355
# 	10%: -2.566891958041675

# %%
df_log1 = np.log(df11)

# %%
plt.plot(df_log)

# %%
df_log2 = np.log(df12)

# %%
plt.plot(df_log2)

# %%
def get_stationarity(timeseries):
    
    # rolling statistics
    rolling_mean = timeseries.rolling(window=12).mean()
    rolling_std = timeseries.rolling(window=12).std()
    
    # rolling statistics plot
    original = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(rolling_mean, color='red', label='Rolling Mean')
    std = plt.plot(rolling_std, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Dickey–Fuller test:
    result = adfuller(timeseries)
    print('ADF Statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

# %%
rolling_mean = df_log1.rolling(window=12).mean()
df_log_minus_mean = df_log1 - rolling_mean
df_log_minus_mean.dropna(inplace=True)
get_stationarity(df_log_minus_mean)
# Out:
# ADF Statistic: -12.054929986615655
# p-value: 2.5465061680334075e-22
# Critical Values:
# 	1%: -3.431534563080626
# 	5%: -2.8620634597003414
# 	10%: -2.5670486363571245

# %%
rolling_mean = df_log2.rolling(window=12).mean()
df_log_minus_mean = df_log2 - rolling_mean
df_log_minus_mean.dropna(inplace=True)
get_stationarity(df_log_minus_mean)
# Out:
# ADF Statistic: -16.374469060477587
# p-value: 2.78982785499939e-29
# Critical Values:
# 	1%: -3.430868768391228
# 	5%: -2.8617692699928945
# 	10%: -2.5668920354374247

# %%
rolling_mean_exp_decay = df_log1.ewm(halflife=12, min_periods=0, adjust=True).mean()
df_log_exp_decay = df_log1 - rolling_mean_exp_decay
df_log_exp_decay.dropna(inplace=True)
get_stationarity(df_log_exp_decay)
# Out:
# ADF Statistic: -9.045209507063792
# p-value: 5.0082566605079086e-15
# Critical Values:
# 	1%: -3.4315337053900734
# 	5%: -2.8620630807614025
# 	10%: -2.567048434635845

# %%
rolling_mean_exp_decay = df_log2.ewm(halflife=12, min_periods=0, adjust=True).mean()
df_log_exp_decay = df_log2 - rolling_mean_exp_decay
df_log_exp_decay.dropna(inplace=True)
get_stationarity(df_log_exp_decay)
# Out:
# ADF Statistic: -13.12234068827063
# p-value: 1.5539221037981586e-24
# Critical Values:
# 	1%: -3.430868275008691
# 	5%: -2.8617690519612213
# 	10%: -2.5668919193806023

# %%
df_log_shift = df_log1 - df_log1.shift()
df_log_shift.dropna(inplace=True)
get_stationarity(df_log_shift)
# Out:
# ADF Statistic: -12.511271380467395
# p-value: 2.6709928337778936e-23
# Critical Values:
# 	1%: -3.43153391969625
# 	5%: -2.862063175444693
# 	10%: -2.567048485038778

# %%
df_log_shift = df_log2 - df_log2.shift()
df_log_shift.dropna(inplace=True)
get_stationarity(df_log_shift)
# Out:
# ADF Statistic: -17.085533767956072
# p-value: 7.65406978597931e-30
# Critical Values:
# 	1%: -3.4308684804706515
# 	5%: -2.861769142757336
# 	10%: -2.5668919677107747

# %%
decomposition = seasonal_decompose(df_log1, freq = 30) 
model = ARIMA(df_log1, order=(2,1,2))
results1 = model.fit(disp=-1)
plt.plot(df_log_shift)
plt.plot(results1.fittedvalues, color='red')

# %%
decomposition = seasonal_decompose(df_log2) 
model = ARIMA(df_log2, order=(2,1,2))
results2 = model.fit(disp=-1)
plt.plot(df_log_shift)
plt.plot(results.fittedvalues, color='red')

# %%
predictions_ARIMA_diff = pd.Series(results1.fittedvalues, copy=True)
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(df_log1.iloc[0], index=df_log1.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(df11)
plt.plot(predictions_ARIMA)

# %%
predictions_ARIMA_diff = pd.Series(results2.fittedvalues, copy=True)
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(df_log2.iloc[0], index=df_log2.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(df12)
plt.plot(predictions_ARIMA)

# %%
results1.plot_predict(1,30000)
# Out:
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
30000/365
# Out:
# 82.1917808219178

# %%
results2.plot_predict(1,30000)
# Out:
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# C:\Users\caballer\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
